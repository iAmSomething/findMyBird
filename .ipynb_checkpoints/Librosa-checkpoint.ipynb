# %%
import librosa
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import librosa.display
import IPython.display as ipd

# %%
ls "./data/"
# Out:
#  B 드라이브의 볼륨: 새 볼륨
#  볼륨 일련 번호: 44E8-BF1C
#
#  B:\3_2\AIProject\findMyBird\data 디렉터리
#
# 2018-12-11  오후 07:55    <DIR>          .
# 2018-12-11  오후 07:55    <DIR>          ..
# 2018-12-11  오후 06:39            44,248 Chicken (1).wav
# 2018-12-11  오후 07:39           176,444 Chicken (10).wav
# 2018-12-11  오후 06:39            22,094 Chicken (11).wav
# 2018-12-11  오후 06:40            88,244 Chicken (12).wav
# 2018-12-11  오후 06:40            44,144 Chicken (13).wav
# 2018-12-11  오후 07:39           176,444 Chicken (14).wav
# 2018-12-11  오후 07:39           176,444 Chicken (15).wav
# 2018-12-11  오후 06:31            22,094 Chicken (16).wav
# 2018-12-11  오후 06:40            11,070 Chicken (17).wav
# 2018-12-11  오후 06:38            11,122 Chicken (18).wav
# 2018-12-11  오후 06:39             8,140 Chicken (19).wav
# 2018-12-11  오후 07:39           384,114 Chicken (2).wav
# 2018-12-11  오후 06:39            44,248 Chicken (20).wav
# 2018-12-11  오후 06:39            22,094 Chicken (21).wav
# 2018-12-11  오후 06:40            88,244 Chicken (22).wav
# 2018-12-11  오후 06:40            44,144 Chicken (23).wav
# 2018-12-11  오후 07:39           384,168 Chicken (3).wav
# 2018-12-11  오후 07:39           384,114 Chicken (4).wav
# 2018-12-11  오후 07:39           384,114 Chicken (5).wav
# 2018-12-11  오후 04:50            44,144 Chicken (6).wav
# 2018-12-11  오후 05:55            88,244 Chicken (7).wav
# 2018-12-11  오후 05:57            22,094 Chicken (8).wav
# 2018-12-11  오후 07:39            44,144 Chicken (9).wav
# 2018-12-11  오후 04:19           176,444 Crow (1).wav
# 2018-12-11  오후 04:19            88,238 Crow (10).wav
# 2018-12-11  오후 04:19            88,238 Crow (11).wav
# 2018-12-11  오후 06:27            88,244 Crow (12).wav
# 2018-12-11  오후 06:27            11,070 Crow (13).wav
# 2018-12-11  오후 06:28            16,044 Crow (14).wav
# 2018-12-11  오후 06:28            22,094 Crow (15).wav
# 2018-12-11  오후 06:29           176,444 Crow (16).wav
# 2018-12-11  오후 06:29            44,170 Crow (17).wav
# 2018-12-11  오후 06:29            11,162 Crow (18).wav
# 2018-12-11  오후 06:30            11,070 Crow (19).wav
# 2018-12-11  오후 04:19           176,444 Crow (2).wav
# 2018-12-11  오후 06:31            22,094 Crow (20).wav
# 2018-12-11  오후 04:19            88,240 Crow (3).wav
# 2018-12-11  오후 04:19            88,242 Crow (4).wav
# 2018-12-11  오후 04:19            88,242 Crow (5).wav
# 2018-12-11  오후 04:19            88,240 Crow (6).wav
# 2018-12-11  오후 04:19            88,240 Crow (7).wav
# 2018-12-11  오후 04:19            88,238 Crow (8).wav
# 2018-12-11  오후 04:19            88,238 Crow (9).wav
# 2018-12-11  오후 04:19            88,244 Hawk (1).wav
# 2018-12-11  오후 04:19           176,444 Hawk (10).wav
# 2018-12-11  오후 04:19           176,444 Hawk (11).wav
# 2018-12-11  오후 04:19           176,444 Hawk (12).wav
# 2018-12-11  오후 04:19           176,444 Hawk (13).wav
# 2018-12-11  오후 04:19           176,444 Hawk (14).wav
# 2018-12-11  오후 04:19           176,444 Hawk (15).wav
# 2018-12-11  오후 04:19            88,244 Hawk (2).wav
# 2018-12-11  오후 04:19            88,244 Hawk (3).wav
# 2018-12-11  오후 04:19            88,244 Hawk (4).wav
# 2018-12-11  오후 04:19            88,244 Hawk (5).wav
# 2018-12-11  오후 04:19            88,244 Hawk (6).wav
# 2018-12-11  오후 04:19            88,244 Hawk (7).wav
# 2018-12-11  오후 04:19           176,440 Hawk (8).wav
# 2018-12-11  오후 04:19           176,440 Hawk (9).wav
# 2018-12-11  오후 04:19           384,114 Owl (1).wav
# 2018-12-11  오후 04:19           384,114 Owl (10).wav
# 2018-12-11  오후 04:19           384,114 Owl (11).wav
# 2018-12-11  오후 04:19           384,114 Owl (12).wav
# 2018-12-11  오후 04:19           384,114 Owl (13).wav
# 2018-12-11  오후 04:19           384,114 Owl (14).wav
# 2018-12-11  오후 04:19           384,114 Owl (15).wav
# 2018-12-11  오후 04:19           384,114 Owl (16).wav
# 2018-12-11  오후 04:19           384,114 Owl (17).wav
# 2018-12-11  오후 04:19           384,114 Owl (18).wav
# 2018-12-11  오후 04:19           384,114 Owl (19).wav
# 2018-12-11  오후 04:19           384,114 Owl (2).wav
# 2018-12-11  오후 04:19           384,114 Owl (20).wav
# 2018-12-11  오후 04:19           384,114 Owl (21).wav
# 2018-12-11  오후 04:19           384,114 Owl (22).wav
# 2018-12-11  오후 04:19           384,110 Owl (23).wav
# 2018-12-11  오후 04:19           384,114 Owl (24).wav
# 2018-12-11  오후 04:19           384,110 Owl (25).wav
# 2018-12-11  오후 04:19           384,110 Owl (26).wav
# 2018-12-11  오후 04:19           384,114 Owl (27).wav
# 2018-12-11  오후 04:19           384,114 Owl (28).wav
# 2018-12-11  오후 04:19           384,110 Owl (29).wav
# 2018-12-11  오후 04:19           384,114 Owl (3).wav
# 2018-12-11  오후 04:19           384,110 Owl (30).wav
# 2018-12-11  오후 04:19           384,110 Owl (31).wav
# 2018-12-11  오후 04:19           384,110 Owl (32).wav
# 2018-12-11  오후 04:19           384,114 Owl (33).wav
# 2018-12-11  오후 04:19           384,114 Owl (34).wav
# 2018-12-11  오후 04:19           384,114 Owl (35).wav
# 2018-12-11  오후 04:19           384,114 Owl (36).wav
# 2018-12-11  오후 04:19           384,114 Owl (37).wav
# 2018-12-11  오후 04:19           384,114 Owl (4).wav
# 2018-12-11  오후 04:19           384,114 Owl (5).wav
# 2018-12-11  오후 04:19           384,114 Owl (6).wav
# 2018-12-11  오후 04:19           384,114 Owl (7).wav
# 2018-12-11  오후 04:19           384,114 Owl (8).wav
# 2018-12-11  오후 04:19           384,114 Owl (9).wav
#               95개 파일          20,505,232 바이트
#                2개 디렉터리  898,739,249,152 바이트 남음

# %%
y, sr = librosa.load("./data/Chicken (1).wav")
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y, sr=sr)

# %%
X = librosa.stft(y)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')

# %%
ipd.Audio('./data/Chicken (1).wav') # load a local WAV file
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 특징 추출 : MFCC

# %%
templist = []
label = [] # 원핫!

for i in range(1, 30):
    y, sr = librosa.load("./data/Owl ({}).wav".format(i))
    mfcc = librosa.feature.mfcc(y=y, sr=sr).T
    templist.append(mfcc)
    label.append(np.array([1,0,0,0]))
dataset = np.asarray(templist)

for i in range(1,17):
    y, sr = librosa.load("./data/Crow ({}).wav".format(i))
    mfcc = librosa.feature.mfcc(y=y, sr=sr).T
    templist.append(mfcc)
    label.append(np.array([0,0,1,0]))
dataset = np.asarray(templist)

for i in range(1, 13):
    y, sr = librosa.load("./data/Hawk ({}).wav".format(i))
    mfcc = librosa.feature.mfcc(y=y, sr=sr).T
    templist.append(mfcc)
    label.append(np.array([0,0,0,1]))
dataset = np.asarray(templist)

for i in range(1, 20):
    y, sr = librosa.load("./data/Chicken ({}).wav".format(i))
    mfcc = librosa.feature.mfcc(y=y, sr=sr).T
    templist.append(mfcc)
    label.append(np.array([0,1,0,0]))
dataset = np.asarray(templist)
print(dataset.shape)

label = np.asarray(label)
print(label.shape)
# Out:
# (76, 44, 20)
# (76, 4)

# %% [markdown]
# # 신경망 모델

# %%
tf.reset_default_graph()
#########
# 옵션 설정
######
learning_rate = 0.0002
total_epoch = 200
batch_size = 1

n_input = mfcc.shape[1]
n_step = mfcc.shape[0]
n_hidden = 200
n_class = 4

#########
# 신경망 모델 구성
######
global_step = tf.Variable(0, trainable=False, name='global_step')

X = tf.placeholder(tf.float32, [None, n_step, n_input])
Y = tf.placeholder(tf.float32, [None, n_class])

with tf.name_scope('Layer'):
    W = tf.Variable(tf.random_normal([n_hidden, n_class]))
    b = tf.Variable(tf.random_normal([n_class]))

# RNN 에 학습에 사용할 셀을 생성합니다
# LSTM 셀을 사용하였습니다.

cell = tf.nn.rnn_cell.BasicLSTMCell(n_hidden)

# RNN 신경망을 생성합니다
outputs, states = tf.nn.dynamic_rnn(cell, X, dtype=tf.float32)

outputs = tf.transpose(outputs, [1, 0, 2])
outputs = outputs[-1]
with tf.name_scope('output'):
    model = tf.matmul(outputs, W) + b

with tf.name_scope('optimizer'):
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=model, labels=Y))
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost, global_step=global_step)
    tf.summary.scalar('cost', cost)

#########
# 신경망 모델 학습
######
sess = tf.Session()
sess.run(tf.global_variables_initializer())
saver = tf.train.Saver(tf.global_variables())

merged = tf.summary.merge_all()
writer = tf.summary.FileWriter('./logs', sess.graph)
total_batch = len(dataset) #int(mnist.train.num_examples/batch_size)

# %% [markdown]
# # 신경망 학습

# %%
for epoch in range(total_epoch):
    total_cost = 0

    for i in range(total_batch):
        batch_xs, batch_ys = (dataset[i], np.array([label[i]]))
        # X 데이터를 RNN 입력 데이터에 맞게 [batch_size, n_step, n_input] 형태로 변환합니다.
        batch_xs = batch_xs.reshape((batch_size, n_step, n_input))

        _, cost_val = sess.run([optimizer, cost],
                               feed_dict={X: batch_xs, Y: batch_ys})
        total_cost += cost_val

    print('Epoch:', '%04d' % (epoch + 1),
          'Avg. cost =', '{}'.format(total_cost / total_batch))
    
    summary = sess.run(merged, feed_dict={X:batch_xs, Y:batch_ys})
    writer.add_summary(summary, global_step=sess.run(global_step))

print('최적화 완료!')
# Out:
# Epoch: 0001 Avg. cost = 5.177652286508467
# Epoch: 0002 Avg. cost = 2.601716250273105
# Epoch: 0003 Avg. cost = 1.5354252053015156
# Epoch: 0004 Avg. cost = 0.8272100205967945
# Epoch: 0005 Avg. cost = 0.47489973561402476
# Epoch: 0006 Avg. cost = 0.31056924915336775
# Epoch: 0007 Avg. cost = 0.17133001149915417
# Epoch: 0008 Avg. cost = 0.1009785279724814
# Epoch: 0009 Avg. cost = 0.06562623794616229
# Epoch: 0010 Avg. cost = 0.04658001369972752
# Epoch: 0011 Avg. cost = 0.03267384349541508
# Epoch: 0012 Avg. cost = 0.025967160998693305
# Epoch: 0013 Avg. cost = 0.021778838093197056
# Epoch: 0014 Avg. cost = 0.018658229357649696
# Epoch: 0015 Avg. cost = 0.01621233092948004
# Epoch: 0016 Avg. cost = 0.014289063552017691
# Epoch: 0017 Avg. cost = 0.012597044263597318
# Epoch: 0018 Avg. cost = 0.011340606770090744
# Epoch: 0019 Avg. cost = 0.010215870175096299
# Epoch: 0020 Avg. cost = 0.00926486994892098
# Epoch: 0021 Avg. cost = 0.008487457168425144
# Epoch: 0022 Avg. cost = 0.007784526894355574
# Epoch: 0023 Avg. cost = 0.007129506295888477
# Epoch: 0024 Avg. cost = 0.006538080038066447
# Epoch: 0025 Avg. cost = 0.006007052987342831
# Epoch: 0026 Avg. cost = 0.005606071007653219
# Epoch: 0027 Avg. cost = 0.005225929009671553
# Epoch: 0028 Avg. cost = 0.004880413138571863
# Epoch: 0029 Avg. cost = 0.004556315694440184
# Epoch: 0030 Avg. cost = 0.004292228322739041
# Epoch: 0031 Avg. cost = 0.00402896825068853
# Epoch: 0032 Avg. cost = 0.0038183491432164374
# Epoch: 0033 Avg. cost = 0.003591046438223681
# Epoch: 0034 Avg. cost = 0.003373484762032843
# Epoch: 0035 Avg. cost = 0.0031145238939117056
# Epoch: 0036 Avg. cost = 0.0029193898967904666
# Epoch: 0037 Avg. cost = 0.00274852740994902
# Epoch: 0038 Avg. cost = 0.002584477909031672
# Epoch: 0039 Avg. cost = 0.0024197223159011343
# Epoch: 0040 Avg. cost = 0.002234896496857848
# Epoch: 0041 Avg. cost = 0.0020149727665499852
# Epoch: 0042 Avg. cost = 0.0018854927044278731
# Epoch: 0043 Avg. cost = 0.0017817777081326743
# Epoch: 0044 Avg. cost = 0.0016905285951368473
# Epoch: 0045 Avg. cost = 0.0016086239948938448
# Epoch: 0046 Avg. cost = 0.0015344715004989428
# Epoch: 0047 Avg. cost = 0.0014666949162670119
# Epoch: 0048 Avg. cost = 0.0014041722328281474
# Epoch: 0049 Avg. cost = 0.0013459072184547807
# Epoch: 0050 Avg. cost = 0.0012910313107807412
# Epoch: 0051 Avg. cost = 0.0012387555410309926
# Epoch: 0052 Avg. cost = 0.001188232838133349
# Epoch: 0053 Avg. cost = 0.0011384255091893703
# Epoch: 0054 Avg. cost = 0.0010929386765676434
# Epoch: 0055 Avg. cost = 0.001051302547990106
# Epoch: 0056 Avg. cost = 0.0010133124742723292
# Epoch: 0057 Avg. cost = 0.000978078513095457
# Epoch: 0058 Avg. cost = 0.0009447655818677815
# Epoch: 0059 Avg. cost = 0.000912825500309186
# Epoch: 0060 Avg. cost = 0.0008818906462543533
# Epoch: 0061 Avg. cost = 0.0008528367450971449
# Epoch: 0062 Avg. cost = 0.0008259086815111292
# Epoch: 0063 Avg. cost = 0.0008001527752292915
# Epoch: 0064 Avg. cost = 0.0007751387935974506
# Epoch: 0065 Avg. cost = 0.0007507259066624341
# Epoch: 0066 Avg. cost = 0.0007276461019321351
# Epoch: 0067 Avg. cost = 0.0007052638763082685
# Epoch: 0068 Avg. cost = 0.0006830881442702344
# Epoch: 0069 Avg. cost = 0.0006628844286727766
# Epoch: 0070 Avg. cost = 0.000640834530040473
# Epoch: 0071 Avg. cost = 0.0006219633032712505
# Epoch: 0072 Avg. cost = 0.0006022141638332437
# Epoch: 0073 Avg. cost = 0.0005848449837284725
# Epoch: 0074 Avg. cost = 0.000567578887120434
# Epoch: 0075 Avg. cost = 0.0005514313324307583
# Epoch: 0076 Avg. cost = 0.0005346332882374171
# Epoch: 0077 Avg. cost = 0.000519059101689759
# Epoch: 0078 Avg. cost = 0.0005042632377266823
# Epoch: 0079 Avg. cost = 0.000482795555547299
# Epoch: 0080 Avg. cost = 0.0004672600426634912
# Epoch: 0081 Avg. cost = 0.00045310396253895355
# Epoch: 0082 Avg. cost = 0.0004387181787421923
# Epoch: 0083 Avg. cost = 0.0004205798739911571
# Epoch: 0084 Avg. cost = 0.0004055719471993095
# Epoch: 0085 Avg. cost = 0.00039202473963864817
# Epoch: 0086 Avg. cost = 0.00037874532447583416
# Epoch: 0087 Avg. cost = 0.0003663598661085799
# Epoch: 0088 Avg. cost = 0.00035298638824231504
# Epoch: 0089 Avg. cost = 0.0003405081577131784
# Epoch: 0090 Avg. cost = 0.0003285416274357096
# Epoch: 0091 Avg. cost = 0.0003164124276284646
# Epoch: 0092 Avg. cost = 0.0003053692588312778
# Epoch: 0093 Avg. cost = 0.0002953567543769216
# Epoch: 0094 Avg. cost = 0.00028516319560810047
# Epoch: 0095 Avg. cost = 0.000275050349551676
# Epoch: 0096 Avg. cost = 0.00026626946413443875
# Epoch: 0097 Avg. cost = 0.0002572958045822074
# Epoch: 0098 Avg. cost = 0.00024853415011630444
# Epoch: 0099 Avg. cost = 0.0002405260792775272
# Epoch: 0100 Avg. cost = 0.00023323996940779294
# Epoch: 0101 Avg. cost = 0.000225692534304232
# Epoch: 0102 Avg. cost = 0.0002183437514777085
# Epoch: 0103 Avg. cost = 0.00021094877180422898
# Epoch: 0104 Avg. cost = 0.00020423842609841957
# Epoch: 0105 Avg. cost = 0.00019742183357607246
# Epoch: 0106 Avg. cost = 0.0001904512329725836
# Epoch: 0107 Avg. cost = 0.000183399996960008
# Epoch: 0108 Avg. cost = 0.00017584436930319139
# Epoch: 0109 Avg. cost = 0.000169575289198657
# Epoch: 0110 Avg. cost = 0.00016276580248362089
# Epoch: 0111 Avg. cost = 0.0001571588555869515
# Epoch: 0112 Avg. cost = 0.00015145878120018837
# Epoch: 0113 Avg. cost = 0.0001458416334632997
# Epoch: 0114 Avg. cost = 0.000141365857901196
# Epoch: 0115 Avg. cost = 0.00013622215715557964
# Epoch: 0116 Avg. cost = 0.00013222917398461744
# Epoch: 0117 Avg. cost = 0.00012771986302601888
# Epoch: 0118 Avg. cost = 0.00012374606428902792
# Epoch: 0119 Avg. cost = 0.0001192029788542545
# Epoch: 0120 Avg. cost = 0.00011531017833171493
# Epoch: 0121 Avg. cost = 0.00011048259389218928
# Epoch: 0122 Avg. cost = 0.00010728293815463387
# Epoch: 0123 Avg. cost = 0.00010382863809797384
# Epoch: 0124 Avg. cost = 0.00010018121352124198
# Epoch: 0125 Avg. cost = 9.748720658745027e-05
# Epoch: 0126 Avg. cost = 9.423327318664203e-05
# Epoch: 0127 Avg. cost = 9.10215974167721e-05
# Epoch: 0128 Avg. cost = 8.844625942048736e-05
# Epoch: 0129 Avg. cost = 8.563108797201686e-05
# Epoch: 0130 Avg. cost = 8.290520500658634e-05
# Epoch: 0131 Avg. cost = 8.022627537416695e-05
# Epoch: 0132 Avg. cost = 7.75911738482717e-05
# Epoch: 0133 Avg. cost = 7.501716449958824e-05
# Epoch: 0134 Avg. cost = 7.246347997754523e-05
# Epoch: 0135 Avg. cost = 6.994895376260202e-05
# Epoch: 0136 Avg. cost = 6.742499262015287e-05
# Epoch: 0137 Avg. cost = 6.483673228530051e-05
# Epoch: 0138 Avg. cost = 6.277554753989092e-05
# Epoch: 0139 Avg. cost = 5.945494649831804e-05
# Epoch: 0140 Avg. cost = 5.602663384289479e-05
# Epoch: 0141 Avg. cost = 5.160897993798579e-05
# Epoch: 0142 Avg. cost = 4.672801375106342e-05
# Epoch: 0143 Avg. cost = 4.325128019784592e-05
# Epoch: 0144 Avg. cost = 4.071072735521927e-05
# Epoch: 0145 Avg. cost = 3.861558807313028e-05
# Epoch: 0146 Avg. cost = 3.693440820581142e-05
# Epoch: 0147 Avg. cost = 3.542417935043536e-05
# Epoch: 0148 Avg. cost = 3.4014307372674435e-05
# Epoch: 0149 Avg. cost = 3.270165936320486e-05
# Epoch: 0150 Avg. cost = 3.147055499986313e-05
# Epoch: 0151 Avg. cost = 3.033982063066195e-05
# Epoch: 0152 Avg. cost = 2.9226326780368e-05
# Epoch: 0153 Avg. cost = 2.815517397573779e-05
# Epoch: 0154 Avg. cost = 2.711224729729248e-05
# Epoch: 0155 Avg. cost = 2.6094412555983426e-05
# Epoch: 0156 Avg. cost = 2.4764469078812562e-05
# Epoch: 0157 Avg. cost = 2.2760070222984185e-05
# Epoch: 0158 Avg. cost = 2.1729670100611997e-05
# Epoch: 0159 Avg. cost = 2.076671241022977e-05
# Epoch: 0160 Avg. cost = 1.9753555759630847e-05
# Epoch: 0161 Avg. cost = 1.8774891613323287e-05
# Epoch: 0162 Avg. cost = 1.7804050741581907e-05
# Epoch: 0163 Avg. cost = 1.6919459102719036e-05
# Epoch: 0164 Avg. cost = 1.6091317813467304e-05
# Epoch: 0165 Avg. cost = 1.5454524827312727e-05
# Epoch: 0166 Avg. cost = 1.4886739822335477e-05
# Epoch: 0167 Avg. cost = 1.435659530840975e-05
# Epoch: 0168 Avg. cost = 1.3879777393947728e-05
# Epoch: 0169 Avg. cost = 1.3432759943243192e-05
# Epoch: 0170 Avg. cost = 1.300770018602667e-05
# Epoch: 0171 Avg. cost = 1.2592050476942668e-05
# Epoch: 0172 Avg. cost = 1.2212476072567083e-05
# Epoch: 0173 Avg. cost = 1.1834469197268796e-05
# Epoch: 0174 Avg. cost = 1.1478421138863987e-05
# Epoch: 0175 Avg. cost = 1.1119235278861675e-05
# Epoch: 0176 Avg. cost = 1.0752206640362553e-05
# Epoch: 0177 Avg. cost = 1.0399293984912555e-05
# Epoch: 0178 Avg. cost = 1.0060497891417023e-05
# Epoch: 0179 Avg. cost = 9.751503298323433e-06
# Epoch: 0180 Avg. cost = 9.43780278433711e-06
# Epoch: 0181 Avg. cost = 9.124101880019745e-06
# Epoch: 0182 Avg. cost = 8.835496620375837e-06
# Epoch: 0183 Avg. cost = 8.509246815566634e-06
# Epoch: 0184 Avg. cost = 8.225346855184057e-06
# Epoch: 0185 Avg. cost = 7.936740840868969e-06
# Epoch: 0186 Avg. cost = 7.674799547791922e-06
# Epoch: 0187 Avg. cost = 7.405015307931624e-06
# Epoch: 0188 Avg. cost = 7.1744438401416824e-06
# Epoch: 0189 Avg. cost = 8.957749316669611e-06
# Epoch: 0190 Avg. cost = 6.761921592669003e-06
# Epoch: 0191 Avg. cost = 6.446650321965003e-06
# Epoch: 0192 Avg. cost = 6.1847084410073335e-06
# Epoch: 0193 Avg. cost = 5.9541369507792e-06
# Epoch: 0194 Avg. cost = 5.729839045804696e-06
# Epoch: 0195 Avg. cost = 5.535343020437572e-06
# Epoch: 0196 Avg. cost = 5.315750458852844e-06
# Epoch: 0197 Avg. cost = 5.108705997370958e-06
# Epoch: 0198 Avg. cost = 4.893818620051829e-06
# Epoch: 0199 Avg. cost = 4.6946165302810374e-06
# Epoch: 0200 Avg. cost = 4.481297330315963e-06
# 최적화 완료!

# %% [markdown]
# ## 모델 저장 , 불러오기

# %%
# saver.save(sess, './model/lstm.ckpt', global_step=global_step)
# Out:
# './model/lstm.ckpt-15200'

# %%
ckpt = tf.train.get_checkpoint_state('./model')
if ckpt and tf.train.checkpoint_exists(ckpt.model_checkpoint_path):
    
    saver.restore(sess, ckpt.model_checkpoint_path)
# Out:
# INFO:tensorflow:Restoring parameters from ./model\lstm.ckpt-16600

# %% [markdown]
# # 모델 테스트

# %%
y, sr = librosa.load("./data/Owl (37).wav")
test_mfcc = librosa.feature.mfcc(y=y, sr=sr).T

test_batch_size = 1
test_xs = test_mfcc.reshape(1, n_step, n_input)

print('정답 레이블 = ', np.argmax(sess.run(model, feed_dict={X:np.array([test_mfcc])})) + 1)
# Out:
# 정답 레이블 =  1

# %%
y, sr = librosa.load("./data/Chicken (20).wav")
test_mfcc = librosa.feature.mfcc(y=y, sr=sr).T

test_batch_size = 1
test_xs = test_mfcc.reshape(1, n_step, n_input)
print('정답 레이블 = ', np.argmax(sess.run(model, feed_dict={X:np.array([test_mfcc])})) + 1)
# Out:
# 정답 레이블 =  2

# %%
y, sr = librosa.load("./data/Crow (19).wav")
test_mfcc = librosa.feature.mfcc(y=y, sr=sr).T

test_batch_size = 1
test_xs = test_mfcc.reshape(1, n_step, n_input)

print('정답 레이블 = ', np.argmax(sess.run(model, feed_dict={X:test_xs})) + 1)
# Out:
# 정답 레이블 =  4

# %%
y, sr = librosa.load("./data/Hawk (15).wav")
test_mfcc = librosa.feature.mfcc(y=y, sr=sr).T

print('정답 레이블 = ', np.argmax(sess.run(model, feed_dict={X:np.array([test_mfcc])})) + 1)
# Out:
# 정답 레이블 =  4

# %%
test_mfcc.shape
# Out:
# (44, 20)

# %% [markdown]
# ## 정확도 측정

# %%
templist = []
test_label = [] # 원핫!

for i in range(30, 38):
    y, sr = librosa.load("./data/Owl ({}).wav".format(i))
    mfcc = librosa.feature.mfcc(y=y, sr=sr).T
    templist.append(mfcc)
    test_label.append(np.array([1,0,0,0]))
test_dataset = np.asarray(templist)

for i in range(17, 20):
    y, sr = librosa.load("./data/Crow ({}).wav".format(i))
    mfcc = librosa.feature.mfcc(y=y, sr=sr).T
    templist.append(mfcc)
    test_label.append(np.array([0,0,1,0]))
test_dataset = np.asarray(templist)

for i in range(13, 16):
    y, sr = librosa.load("./data/Hawk ({}).wav".format(i))
    mfcc = librosa.feature.mfcc(y=y, sr=sr).T
    templist.append(mfcc)
    test_label.append(np.array([0,0,0,1]))
test_dataset = np.asarray(templist)

for i in range(20, 24):
    y, sr = librosa.load("./data/Chicken ({}).wav".format(i))
    mfcc = librosa.feature.mfcc(y=y, sr=sr).T
    templist.append(mfcc)
    test_label.append(np.array([0,1,0,0]))
test_dataset = np.asarray(templist)
print(test_dataset.shape)

test_label = np.asarray(test_label)
print(test_label.shape)
# Out:
# (18, 44, 20)
# (18, 4)

# %%
np.argmax(sess.run(model, feed_dict={X:test_dataset}), axis=1)
# Out:
# array([0, 0, 0, 0, 1, 1, 1, 3, 1, 2, 0, 3, 3, 3, 1, 1, 1, 1], dtype=int64)

# %%
np.argmax(test_label, axis=1)
# Out:
# array([0, 0, 0, 0, 0, 0, 0, 0, 2, 2, 2, 3, 3, 3, 1, 1, 1, 1], dtype=int64)

# %%
correct_prediction=tf.equal(np.argmax(sess.run(model, feed_dict={X:test_dataset}), axis=1),np.argmax(test_label, axis=1))
accuracy=tf.reduce_mean(tf.cast(correct_prediction,tf.float32))
print("Testing Accuracy:", sess.run(accuracy))
# Out:
# Testing Accuracy: 0.8333333
